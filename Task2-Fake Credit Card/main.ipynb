# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
from imblearn.under_sampling import RandomUnderSampler

# %%
data=pd.read_csv("creditcard.csv")

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
data.shape
# Out:
# (284807, 31)

# %%
#Prediction Column
data["Class"].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# No Null Values
data.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#Duplicate Rows
data[data.duplicated()]
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 33          26.0 -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223
# 35          26.0 -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983
# 113         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 114         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 115         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# ...          ...       ...       ...       ...       ...       ...       ...
# 282987  171288.0  1.912550 -0.455240 -1.750654  0.454324  2.089130  4.160019
# 283483  171627.0 -1.464380  1.368119  0.815992 -0.601282 -0.689115 -0.487154
# 283485  171627.0 -1.457978  1.378203  0.811515 -0.603760 -0.711883 -0.471672
# 284191  172233.0 -2.667936  3.160505 -3.355984  1.007845 -0.377397 -0.109730
# 284193  172233.0 -2.691642  3.123168 -3.339407  1.017018 -0.293095 -0.167054
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 33      0.711206  0.176066 -0.286717  ...  0.046949  0.208105 -0.185548
# 35      0.693039  0.179742 -0.285642  ...  0.049526  0.206537 -0.187108
# 113    -0.036715  0.350995  0.118950  ...  0.102520  0.605089  0.023092
# 114    -0.036715  0.350995  0.118950  ...  0.102520  0.605089  0.023092
# 115    -0.036715  0.350995  0.118950  ...  0.102520  0.605089  0.023092
# ...          ...       ...       ...  ...       ...       ...       ...
# 282987 -0.881302  1.081750  1.022928  ... -0.524067 -1.337510  0.473943
# 283483 -0.303778  0.884953  0.054065  ...  0.287217  0.947825 -0.218773
# 283485 -0.282535  0.880654  0.052808  ...  0.284205  0.949659 -0.216949
# 284191 -0.667233  2.309700 -1.639306  ...  0.391483  0.266536 -0.079853
# 284193 -0.745886  2.325616 -1.634651  ...  0.402639  0.259746 -0.086606
#
#              V24       V25       V26       V27       V28  Amount  Class
# 33      0.001031  0.098816 -0.552904 -0.073288  0.023307    6.14      0
# 35      0.000753  0.098117 -0.553471 -0.078306  0.025427    1.77      0
# 113    -0.626463  0.479120 -0.166937  0.081247  0.001192    1.18      0
# 114    -0.626463  0.479120 -0.166937  0.081247  0.001192    1.18      0
# 115    -0.626463  0.479120 -0.166937  0.081247  0.001192    1.18      0
# ...          ...       ...       ...       ...       ...     ...    ...
# 282987  0.616683 -0.283548 -1.084843  0.073133 -0.036020   11.99      0
# 283483  0.082926  0.044127  0.639270  0.213565  0.119251    6.82      0
# 283485  0.083250  0.044944  0.639933  0.219432  0.116772   11.93      0
# 284191 -0.096395  0.086719 -0.451128 -1.183743 -0.222200   55.66      0
# 284193 -0.097597  0.083693 -0.453584 -1.205466 -0.213020   36.74      0
#
# [1081 rows x 31 columns]

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (283726, 31)

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
from imblearn.over_sampling import RandomOverSampler,

# %%
x=data.drop(columns="Class")

# %%
y=data["Class"]

# %%
randomOverSampler=RandomOverSampler()

# %%
randomUnderSampler=RandomUnderSampler()

# %%
x_resampled, y_resampled = randomOverSampler.fit_resample(x, y)

# %%
x_resampled
# Out:
#             Time         V1         V2         V3        V4         V5  \
# 0            0.0  -1.359807  -0.072781   2.536347  1.378155  -0.338321
# 1            0.0   1.191857   0.266151   0.166480  0.448154   0.060018
# 2            1.0  -1.358354  -1.340163   1.773209  0.379780  -0.503198
# 3            1.0  -0.966272  -0.185226   1.792993 -0.863291  -0.010309
# 4            2.0  -1.158233   0.877737   1.548718  0.403034  -0.407193
# ...          ...        ...        ...        ...       ...        ...
# 566501  143354.0   1.118331   2.074439  -3.837518  5.448060   0.071816
# 566502   26523.0 -18.474868  11.586381 -21.402917  6.038515 -14.451158
# 566503   26585.0 -19.856322  12.095893 -22.464083  6.115541 -15.148022
# 566504  160791.0   2.132386   0.705608  -3.530759  0.514779   1.527175
# 566505   82289.0  -1.464897   1.975528  -1.077145  2.819191   0.069850
#
#               V6         V7         V8        V9  ...       V20       V21  \
# 0       0.462388   0.239599   0.098698  0.363787  ...  0.251412 -0.018307
# 1      -0.082361  -0.078803   0.085102 -0.255425  ... -0.069083 -0.225775
# 2       1.800499   0.791461   0.247676 -1.514654  ...  0.524980  0.247998
# 3       1.247203   0.237609   0.377436 -1.387024  ... -0.208038 -0.108300
# 4       0.095921   0.592941  -0.270533  0.817739  ...  0.408542 -0.009431
# ...          ...        ...        ...       ...  ...       ...       ...
# 566501 -1.020509  -1.808574   0.521744 -2.032638  ...  0.163513  0.289861
# 566502 -4.146524 -14.856124  12.431140 -4.053353  ...  1.577924  1.741136
# 566503 -4.346724 -15.648507  13.276805 -3.974162  ...  1.582930  1.750730
# 566504 -1.716268   1.132791  -0.574214  0.128904  ... -0.211167  0.163739
# 566505 -0.789044  -1.196101   0.673654 -1.363724  ...  0.048969  0.174099
#
#              V22       V23       V24       V25       V26       V27       V28  \
# 0       0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1      -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2       0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3       0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4       0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
# ...          ...       ...       ...       ...       ...       ...       ...
# 566501 -0.172718 -0.021910 -0.376560  0.192817  0.114107  0.500996  0.259533
# 566502 -1.251138 -0.396219  0.095706  1.322751 -0.217955  1.628793  0.482248
# 566503 -1.409636 -0.809809  0.121397  1.350300 -0.224292  1.597621  0.476920
# 566504  0.703910 -0.245076  0.460049  0.920281 -0.216586 -0.026219 -0.025001
# 566505 -0.272505 -0.031549 -0.406166  0.157769 -0.104393  0.073796 -0.041570
#
#         Amount
# 0       149.62
# 1         2.69
# 2       378.66
# 3       123.50
# 4        69.99
# ...        ...
# 566501    1.00
# 566502   99.99
# 566503   99.99
# 566504    1.00
# 566505    1.00
#
# [566506 rows x 30 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, test_size=0.2, random_state=42)


scaler = StandardScaler()
X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)

# %%
model_random = RandomForestClassifier(n_estimators=100, random_state=42)
model_random.fit(X_train, y_train)

# Membuat prediksi
y_pred = model_random.predict(X_test)

# Evaluasi model
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[56460     3]
#  [    0 56839]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56463
#            1       1.00      1.00      1.00     56839
#
#     accuracy                           1.00    113302
#    macro avg       1.00      1.00      1.00    113302
# weighted avg       1.00      1.00      1.00    113302

# %%
x_resampled, y_resampled = randomUnderSampler.fit_resample(x, y)

# %%
x_resampled
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 268472  163228.0 -0.308791  0.193386  0.641245 -1.708744 -0.746617 -0.123684
# 258848  158851.0 -0.022386  1.626061 -1.496345  0.307141  2.037794 -1.201878
# 148974   90387.0 -0.617743  1.228172 -0.001882 -0.463948  0.080589 -0.909489
# 12803    22466.0  1.203498 -0.429395  0.660039 -0.877071 -0.524396  0.504578
# 41244    40603.0  1.139782 -0.542410  0.917410  0.392081 -0.832252  0.744538
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 268472 -0.099552  0.435856  0.837829  ...  0.047623  0.163372  0.389234
# 258848  1.587157 -0.418489 -1.109107  ...  0.176899  0.054588  0.373396
# 148974  0.399831  0.331877  1.114202  ... -0.099304 -0.349794 -0.724749
# 12803  -0.884418  0.253243  2.977378  ... -0.171845 -0.139681  0.048415
# 41244  -0.978138  0.371401 -0.952534  ... -0.560088 -0.072847  0.305909
# ...          ...       ...       ...  ...       ...       ...       ...
# 279863 -0.882850  0.697211 -2.064945  ...  1.252967  0.778584 -0.319189
# 280143 -1.413170  0.248525 -1.127396  ...  0.226138  0.370612  0.028234
# 280149 -2.234739  1.210158 -0.652250  ...  0.247968  0.751826  0.834108
# 281144 -2.208002  1.058733 -1.632333  ...  0.306271  0.583276 -0.269209
# 281674  0.223050 -0.068384  0.577829  ... -0.017652 -0.164350 -0.295135
#
#              V23       V24       V25       V26       V27       V28  Amount
# 268472  0.185260 -0.652067 -0.639169  0.500633 -0.086430 -0.008693   88.61
# 258848 -0.383547  0.477064 -0.004106  0.794743  0.129738  0.227049    0.76
# 148974  0.173707 -0.015475 -0.500049  0.086459  0.196635  0.074160    9.72
# 12803  -0.117386 -0.896960  0.468662 -0.658702  0.073099  0.007317   11.85
# 41244   0.018619 -0.326995  0.227611 -0.201869  0.098381  0.023275   25.00
# ...          ...       ...       ...       ...       ...       ...     ...
# 279863  0.639419 -0.294885  0.537503  0.788395  0.292680  0.147968  390.00
# 280143 -0.145640 -0.081049  0.521875  0.739467  0.389152  0.186637    0.76
# 280149  0.190944  0.032070 -0.739695  0.471111  0.385107  0.194361   77.89
# 281144 -0.456108 -0.183659 -0.328168  0.606116  0.884876 -0.253700  245.00
# 281674 -0.072173 -0.450261  0.313267 -0.289617  0.002988 -0.015309   42.53
#
# [946 rows x 30 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, test_size=0.2, random_state=42)


scaler = StandardScaler()
X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)

# %%
model_random = RandomForestClassifier(n_estimators=100, random_state=42)
model_random.fit(X_train, y_train)

# Membuat prediksi
y_pred = model_random.predict(X_test)

# Evaluasi model
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[86  2]
#  [12 90]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.92        88
#            1       0.98      0.88      0.93       102
#
#     accuracy                           0.93       190
#    macro avg       0.93      0.93      0.93       190
# weighted avg       0.93      0.93      0.93       190
