# %% [markdown]
# # Importing Necessary Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
from imblearn.under_sampling import RandomUnderSampler
from sklearn.linear_model import  LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %% [markdown]
# # Reading The Data

# %%
data=pd.read_csv("creditcard.csv")

# %% [markdown]
# # Basic EDA

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
#Prediction Column
data["Class"].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# No Null Values
data.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#Duplicate Rows
data[data.duplicated()]
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 33          26.0 -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223
# 35          26.0 -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983
# 113         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 114         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 115         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# ...          ...       ...       ...       ...       ...       ...       ...
# 282987  171288.0  1.912550 -0.455240 -1.750654  0.454324  2.089130  4.160019
# 283483  171627.0 -1.464380  1.368119  0.815992 -0.601282 -0.689115 -0.487154
# 283485  171627.0 -1.457978  1.378203  0.811515 -0.603760 -0.711883 -0.471672
# 284191  172233.0 -2.667936  3.160505 -3.355984  1.007845 -0.377397 -0.109730
# 284193  172233.0 -2.691642  3.123168 -3.339407  1.017018 -0.293095 -0.167054
#
# ...

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Creating Dependent and Independnt Variable

# %%
x=data.drop(columns="Class")
y=data["Class"]

# %% [markdown]
# ## OverSampling And UnderSampling

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
randomOverSampler=RandomOverSampler()

# %%
randomUnderSampler=RandomUnderSampler()

# %%
x_resampled, y_resampled = randomOverSampler.fit_resample(x, y)

# %%
x_resampled
# Out:
#             Time         V1         V2         V3         V4         V5  \
# 0            0.0  -1.359807  -0.072781   2.536347   1.378155  -0.338321
# 1            0.0   1.191857   0.266151   0.166480   0.448154   0.060018
# 2            1.0  -1.358354  -1.340163   1.773209   0.379780  -0.503198
# 3            1.0  -0.966272  -0.185226   1.792993  -0.863291  -0.010309
# 4            2.0  -1.158233   0.877737   1.548718   0.403034  -0.407193
# ...          ...        ...        ...        ...        ...        ...
# 568625  118532.0  -5.961457   5.313382  -6.674320   6.028975  -1.387560
# 568626  102542.0  -1.456876   3.740306  -7.404518   7.440964  -1.549878
# 568627   41204.0  -8.440284   6.147653 -11.683706   6.702780  -8.155839
# 568628   75851.0  -4.793667   3.418911  -5.074445   4.035987  -3.527875
# 568629   95628.0 -17.518909  12.572118 -19.038538  11.190895 -13.554721
#
#               V6         V7        V8        V9  ...       V20       V21  \
# ...

# %%
x_resampled, y_resampled = randomUnderSampler.fit_resample(x, y)

# %%
x_resampled
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 189309  128345.0 -14.026514 -15.733166 -1.163953  1.160607  3.700101
# 248515  153978.0  -1.370805  -1.576157  0.107768 -2.533271 -2.002829
# 242687  151601.0   2.040211  -0.146975 -2.955934 -0.578356  2.609358
# 69965    53654.0  -2.929930  -4.546605  1.234867 -1.726152 -0.343619
# 204392  135255.0  -0.253161   1.264191 -0.686842 -0.599983  0.667620
# ...          ...        ...        ...       ...       ...       ...
# 279863  169142.0  -1.927883   1.125653 -4.518331  1.749293 -1.566487
# 280143  169347.0   1.378559   1.289381 -5.004247  1.411850  0.442581
# 280149  169351.0  -0.676143   1.126366 -2.213700  0.468308 -1.120541
# 281144  169966.0  -3.113832   0.585864 -5.399730  1.817092 -0.840618
# 281674  170348.0   1.991976   0.158476 -2.583441  0.408670  1.151147
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, test_size=0.2, random_state=42)


scaler = StandardScaler()
X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)

# %% [markdown]
# # Feature Selection

# %%
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import SelectKBest

# %%
X_new = SelectKBest(f_classif, k=5).fit_transform(x, y)

# %%
X_new[0]
# Out:
# array([ 0.09079417, -0.61780086, -0.31116935, -0.47040053,  0.20797124])

# %%
x_resampled, y_resampled = randomUnderSampler.fit_resample(X_new, y)
xtrain, xtest, ytrain, ytest = train_test_split(x_resampled, y_resampled, test_size=0.2, random_state=42)


scaler = StandardScaler()
X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)

# %%
modelLinearRegression = LogisticRegression()
modelLinearRegression.fit(xtrain,ytrain)
ypredLogisticRegresion=modelLinearRegression.predict(xtest)

# %%
print("Logistic Regression Results:")
print("Confusion Matrix:")
print(confusion_matrix(ytest, ypredLogisticRegresion))
print("\nClassification Report:")
print(classification_report(ytest, ypredLogisticRegresion))
# Out:
# Logistic Regression Results:
# Confusion Matrix:
# [[96  3]
#  [14 84]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92        99
#            1       0.97      0.86      0.91        98
#
#     accuracy                           0.91       197
#    macro avg       0.92      0.91      0.91       197
# weighted avg       0.92      0.91      0.91       197

# %% [markdown]
# ## User Input

# %%
result=modelLinearRegression.predict([[0.09079417, -0.61780086, -0.31116935, -0.47040053,  0.20797124]])
if result:
    print(f"The Credit Card is Not Fake")
else:
    print("The Credit Card is Fake")
# Out:
# The Credit Card is Fake

# %% [markdown]
# # SVC

# %%
model_svc = SVC()
model_svc.fit(xtrain, ytrain)
ypred_svc = model_svc.predict(xtest)

print("Support Vector Classifier Results:")
print("Confusion Matrix:")
print(confusion_matrix(ytest, ypred_svc))
print("\nClassification Report:")
print(classification_report(ytest, ypred_svc))
# Out:
# Support Vector Classifier Results:
# Confusion Matrix:
# [[99  0]
#  [18 80]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        99
#            1       1.00      0.82      0.90        98
#
#     accuracy                           0.91       197
#    macro avg       0.92      0.91      0.91       197
# weighted avg       0.92      0.91      0.91       197

# %% [markdown]
# ## User Input

# %%
result=model_svc.predict([[0.09079417, -0.61780086, -0.31116935, -0.47040053,  0.20797124]])
if result:
    print(f"The Credit Card is Not Fake")
else:
    print("The Credit Card is Fake")
# Out:
# The Credit Card is Fake

# %% [markdown]
# # Decision Tree

# %%
model_decision_tree = DecisionTreeClassifier()
model_decision_tree.fit(xtrain, ytrain)
ypred_decision_tree = model_decision_tree.predict(xtest)

print("Decision Tree Classifier Results:")
print("Confusion Matrix:")
print(confusion_matrix(ytest, ypred_decision_tree))
print("\nClassification Report:")
print(classification_report(ytest, ypred_decision_tree))
# Out:
# Decision Tree Classifier Results:
# Confusion Matrix:
# [[91  8]
#  [10 88]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91        99
#            1       0.92      0.90      0.91        98
#
#     accuracy                           0.91       197
#    macro avg       0.91      0.91      0.91       197
# weighted avg       0.91      0.91      0.91       197

# %% [markdown]
# ## USer Input

# %%
result=model_decision_tree.predict([[0.09079417, -0.61780086, -0.31116935, -0.47040053,  0.20797124]])
if result:
    print(f"The Credit Card is Not Fake")
else:
    print("The Credit Card is Fake")
# Out:
# The Credit Card is Fake

# %% [markdown]
# # Random Forest Regressor

# %%
model_random_forest = RandomForestClassifier(n_estimators=100, random_state=42)
model_random_forest.fit(xtrain, ytrain)
ypred_random_forest = model_random_forest.predict(xtest)

print("Random Forest Classifier Results:")
print("Confusion Matrix:")
print(confusion_matrix(ytest, ypred_random_forest))
print("\nClassification Report:")
print(classification_report(ytest, ypred_random_forest))
# Out:
# Random Forest Classifier Results:
# Confusion Matrix:
# [[94  5]
#  [11 87]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92        99
#            1       0.95      0.89      0.92        98
#
#     accuracy                           0.92       197
#    macro avg       0.92      0.92      0.92       197
# weighted avg       0.92      0.92      0.92       197

# %% [markdown]
# # User Input

# %%
result=model_random_forest.predict([[0.09079417, -0.61780086, -0.31116935, -0.47040053,  0.20797124]])
if result:
    print(f"The Credit Card is Not Fake")
else:
    print("The Credit Card is Fake")
# Out:
# The Credit Card is Fake
